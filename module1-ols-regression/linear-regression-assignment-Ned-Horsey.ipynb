# %% [markdown]
# # King County Housing Data - Linear Regression Assignment
#
# Data for this assignment was obtained from Kaggle: <https://www.kaggle.com/harlfoxem/housesalesprediction>
#
# Complete the following challenges below to improve iteratively your home price estimation and practice implementing predictive linear regression models.

# %% [markdown]
# # Bivariate Regression
#
# Pick the X variable that you think will be the most correlated with Y.
#
# Split your dataset into a 20-80 train-test-split (80% of data for training, and 20% for testing).
#
# Train a regression model using this single X and single Y variable. Once you have trained the model and obtained its coefficients, plot the points on a graph and fit your line of best fit to the graph.
#
# Report your Root Mean Squared Error and R-Squared for this model.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from math import sqrt


df = pd.read_csv('https://raw.githubusercontent.com/ryanleeallred/datasets/master/kc_house_data.csv')
pd.set_option('display.max_columns', 100)
print(df.shape)
df.head()
# Out:
# (21613, 21)
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0           0     0          3      7        1180
# 1      7242     2.0           0     0          3      7        2170
# 2     10000     1.0           0     0          3      6         770
# 3      5000     1.0           0     0          5      7        1050
# 4      8080     1.0           0     0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
##### Your Code Here #####
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0           0     0          3      7        1180
# 1      7242     2.0           0     0          3      7        2170
# 2     10000     1.0           0     0          3      6         770
# 3      5000     1.0           0     0          5      7        1050
# 4      8080     1.0           0     0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
# add a constant to offset intercept (only necessary for single variable regression)
features = ['sqft_living']


X = df[features]
# make it a colum vector by inserting an axis along the second dimension
X= np.array(X).reshape(-1,1)

target = df['price']

y= target



# y.values.reshape(-1,1)

X_train, X_test, y_train, y_test = train_test_split(X,y, train_size=0.8, test_size=0.2, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((17290, 1), (4323, 1), (17290,), (4323,))

# %%
model = LinearRegression()

model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
pd.Series(model.coef_, features), print('\n Intercept: ', model.intercept_)
# Out:
#  Intercept:  -41999.18604
# (sqft_living    279.554779
#  dtype: float64, None)

# %%
# Now we score the X_test data vs the y_test data


print('Coefficients: \n', model.coef_)
print('Root Mean Squared Error: \n', sqrt(mean_squared_error(y_test, model.predict(X_test))))
print('R2 Score: \n', model.score(X_test, y_test))
# Out:
# Coefficients:
#  [ 279.55477932]
# Root Mean Squared Error:
#  276559.1746114673
# R2 Score:
#  0.494069053891

# %% [markdown]
# Surprise, surprise, a single variable regression explains less than half of the price variation.

# %%
plt.scatter(x=df['sqft_living'], y=df['price']);

plt.plot(X_test, model.predict(X_test), color='red');
plt.title('sqft_living regressed on price', fontsize=15);

# %% [markdown]
# # Two-variable Multiple Regression
#
# To ramp up slowly, pick a second X variable that you think will be the most correlated with Y.
#
# Split your dataset into a 80-20 train-test-split (80% of data for training, and 20% for testing).
#
# Train a regression model using these two X variables. Once you have trained the model and obtained its coefficients, plot the points on a graph and fit your **plane** of best fit to the graph.
#
# Report your Root Mean Squared Error and R-squared for this model.

# %%
##### Your Code Here #####
# ok, let's get clever, 

# features will be sqft of living space and quality of house
features = ['sqft_living', 'grade']
X = df[features]

# target is still price
y= df['price']


# split data
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size=0.8, test_size=0.2, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((17290, 2), (4323, 2), (17290,), (4323,))

# %%
model = LinearRegression()

# define and fit model
model.fit(X_train, y_train)

# Now we score the X_test data vs the y_test data
print('Coefficients: \n', model.coef_)
print('Root Mean Squared Error: \n', sqrt(mean_squared_error(y_test, model.predict(X_test))))
print('R2 Score: \n', model.score(X_test, y_test))
# Out:
# Coefficients:
#  [   185.10393866  96261.37224464]
# Root Mean Squared Error:
#  264262.2149524915
# R2 Score:
#  0.538060345346

# %% [markdown]
# Ok, we did a little bit better, now we'll plot this b****h

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

# nuke the size
from pylab import rcParams
rcParams['figure.figsize'] = 19, 10

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot Points on 3D plot
ax.scatter(df['sqft_living'], df['grade'], df['price'],c='red')

beta_0 = model.intercept_
beta_i = model.coef_


# Set axes to size of scatter data
x1 = np.array(ax.get_xlim())
y1 = np.array(ax.get_ylim())
xx, yy = np.meshgrid(x1,y1)
zz = beta_i[0]*xx + beta_i[1]*yy + beta_0


# Plot Plane
plt3d = plt.gca(projection='3d')


# Add Opacity to Plane 
plt3d.plot_surface(xx, yy, zz,alpha=0.5)
plt.title("Regression Plane")
ax.set_xlabel('sqft_living')
ax.set_ylabel('grade')
ax.set_zlabel('price')
plt.show();

# %% [markdown]
# # Multiple Regression
#
# Now using all available X variables, split your data into test and training datasets, train your model, obtain its coefficients, and report the Root Mean Squared Error and R-squared values.

# %%
##### Your Code Here #####

# deal with the time column:

# df['date'] = df['date'].str.replace('T000000', '')
# df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)

# everything is a feature now (I couldn't handle date so dropped it)
X = df.drop(columns=['price','date'])
y= df['price']


X_train, X_test, y_train, y_test = train_test_split(X,y, train_size=0.8, test_size=0.2, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((17290, 19), (4323, 19), (17290,), (4323,))

# %%
model = LinearRegression()

# define and fit model
model.fit(X_train, y_train)

# Now we score the X_test data vs the y_test data
print('Coefficients: \n', model.coef_)
print('Root Mean Squared Error: \n', sqrt(mean_squared_error(y_test, model.predict(X_test))))
print('R2 Score: \n', model.score(X_test, y_test))
# Out:
# Coefficients:
#  [ -1.33978221e-06  -3.43074736e+04   4.45861014e+04   1.08944477e+02
#    8.05637972e-02   7.01981320e+03   5.61992102e+05   5.37898653e+04
#    2.43817431e+04   9.47120482e+04   6.99457983e+01   3.89986790e+01
#   -2.68205192e+03   2.02428706e+01  -5.51831873e+02   5.95402284e+05
#   -1.92574700e+05   2.11354355e+01  -3.39559834e-01]
# Root Mean Squared Error:
#  212520.1585283156
# R2 Score:
#  0.701244873588

# %% [markdown]
# # Stretch Goals
#
# Pick from these stretch goals the tasks that you feel like will be the most beneficial for you.
#
# - Start to research Polynomial Regression and Log-Linear Regression (tomorrow's topics). Find a new regression dataset and try to implement one of these models.
# - Research "Feature Engineering" see what features you can engineer on the above dataset. How much are you able to improve your accuracy with feature engineering?
# - Explore the concept of $R^2$, learn how it is calculated and how it relates to covariance, correlation, and variance.
# - Further explore the concept of "Model Validation" - we'll spend a whole week on this soon. What other measures of model accuracy could we have used besides Root Mean Squared Error?
# - AMES Housing Prediction Kaggle Competition: <https://www.kaggle.com/c/house-prices-advanced-regression-techniques>
# - **WRITE A BLOG POST** explaining the basics of Linear Regression.
#
# Remember to share your findings in the slack channel. :)

# %%
# Deal with that datetime object

# df['date'] = df['date'].str.replace('T000000', '')
# df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# df['date'] =

# %%
# I want to use PCA to see if I can compress the features of this dataset
from sklearn.decomposition import PCA 
from sklearn.cluster import KMeans 
from sklearn.preprocessing import StandardScaler

# %%
# I did a Kmeans clutser analysis for no reason, plz ignore


df_k = df.drop(columns=['price','date'])

# I'm going to make an elbow graph to get a quick idea of how many K's I want
data_transformed = df.loc[:,df_k.columns.tolist()].values

sum_of_squared_distances = []

K = range(1,len(df_k.columns.tolist()))

for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(data_transformed)
    sum_of_squared_distances.append(km.inertia_)

# Data for plotting
x = K
y = sum_of_squared_distances

fig, ax = plt.subplots()
ax.plot(x, y, 'bx-')

ax.set(xlabel='k', ylabel='sum of squared distances',
       title='Optimal K Elbow')
ax.grid()

# fig.savefig("test.png")
plt.show()

# %%
# remove redundant features and make zipcodes a categorical
df_k = df_k.drop(columns=['lat','long','id'])

# %%
df_k.head().T
# Out:
#                      0         1        2        3        4
# bedrooms           3.0      3.00      2.0      4.0      3.0
# bathrooms          1.0      2.25      1.0      3.0      2.0
# sqft_living     1180.0   2570.00    770.0   1960.0   1680.0
# sqft_lot        5650.0   7242.00  10000.0   5000.0   8080.0
# floors             1.0      2.00      1.0      1.0      1.0
# waterfront         0.0      0.00      0.0      0.0      0.0
# view               0.0      0.00      0.0      0.0      0.0
# condition          3.0      3.00      3.0      5.0      3.0
# grade              7.0      7.00      6.0      7.0      8.0
# sqft_above      1180.0   2170.00    770.0   1050.0   1680.0
# sqft_basement      0.0    400.00      0.0    910.0      0.0
# yr_built        1955.0   1951.00   1933.0   1965.0   1987.0
# yr_renovated       0.0   1991.00      0.0      0.0      0.0
# zipcode        98178.0  98125.00  98028.0  98136.0  98074.0
# sqft_living15   1340.0   1690.00   2720.0   1360.0   1800.0
# ...

# %%
# Note, this code can from Will Cotton, a true math-OG
import statistics as stat

# first prepare dataframe with normalization:

x = df_k.loc[:, df_k.columns.tolist()].values

x = StandardScaler().fit_transform(x)

n = len(df_k.columns.tolist())-1



pca = PCA(n_components = n)

principalComponents = pca.fit_transform(x)


labels = ['pc' + str(num) for num in range(1, n)]


principalComp = pd.DataFrame(data = principalComponents,
                            columns = labels)

std_devs = [stat.stdev(principalComp[col].values) for col in labels]
variances = [std**2 for std in std_devs]

sum_var = sum(variances)
prop_varex = [(variance/sum_var) for variance in variances]
j=0
cum_varex=np.zeros(30)
while j < len(variances):
  cum_varex[j] = sum(prop_varex[:j+1])
  j+=1
  
fig = plt.figure(figsize = (17,8));
fig.add_axes()
ax2=fig.add_subplot(111)
ax2.bar(x=labels, height=cum_varex)#, cmap = 'Greens')
ax2.axhline(0.5, color='r')
ax2.axhline(0.75, color='y')
ax2.axhline(0.9, color='g')
plt.title('Cumulative Explaind Variance vs Principle Component Features');
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in create_block_manager_from_blocks(blocks, axes)
#    1650                 blocks = [make_block(values=blocks[0],
# -> 1651                                      placement=slice(0, len(axes[0])))]
#    1652
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/blocks.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    3094
# -> 3095     return klass(values, ndim=ndim, placement=placement)
#    3096
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/blocks.py in __init__(self, values, placement, ndim)
#      86                 'Wrong number of items passed {val}, placement implies '
# ---> 87                 '{mgr}'.format(val=len(self.values), mgr=len(self.mgr_locs)))
#      88
#
# ...

# %%
# looks like we get optimal clusters
